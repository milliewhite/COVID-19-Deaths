# %% [markdown]
# # Millie White
# # Personal Project
# # Conditions Contributing to Deaths Involving Coronavirus Disease 2019 (COVID-19), by Age Group and State, United States

# %%
# %matplotlib inline

import pandas as pd
from matplotlib import pyplot as plt

# increase the size and quality of any plots we produce
import matplotlib as mpl

mpl.rcParams["figure.dpi"] = 300

# %%
import pandas as pd
import numpy as np

# %%
#open the csv file as a pandas dataframe
my_df = pd.read_csv ('Conditions_contributing_to_COVID-19___by_age_group_and_state__United_States.csv')
my_df.tail(5)
my_df.size #the number of rows
# Out:
# 3303720

# %%
my_df.head(5)
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  04/25/2021  01/01/2020  04/24/2021  By Total   NaN    NaN  United States
# 1  04/25/2021  01/01/2020  04/24/2021  By Total   NaN    NaN  United States
# 2  04/25/2021  01/01/2020  04/24/2021  By Total   NaN    NaN  United States
# 3  04/25/2021  01/01/2020  04/24/2021  By Total   NaN    NaN  United States
# 4  04/25/2021  01/01/2020  04/24/2021  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID-19 Deaths  Number of Mentions Flag
# 0            370.0               384.0  NaN
# 1           1692.0              1731.0  NaN
# 2           4548.0              4664.0  NaN
# 3          13587.0             13964.0  NaN
# 4          34936.0             35852.0  NaN

# %%
#make copy of dataframe
df = my_df.copy()
df.head(1)
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  04/25/2021  01/01/2020  04/24/2021  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
#
#    COVID-19 Deaths  Number of Mentions Flag
# 0            370.0               384.0  NaN

# %%
#columns in dataframe
df.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'State', 'Condition Group', 'Condition', 'ICD10_codes', 'Age Group',
#        'COVID-19 Deaths', 'Number of Mentions', 'Flag'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')#remove spaces
df.columns = df.columns.str.replace('-','')#remove hyphens
df.columns
# Out:
# Index(['Data_As_Of', 'Start_Date', 'End_Date', 'Group', 'Year', 'Month',
#        'State', 'Condition_Group', 'Condition', 'ICD10_codes', 'Age_Group',
#        'COVID19_Deaths', 'Number_of_Mentions', 'Flag'],
#       dtype='object')

# %% [markdown]
# # Condition Groups

# %%
#different condition groups
#All values in the condition group
df['Condition_Group'].unique()
# Out:
# array(['Respiratory diseases', 'Circulatory diseases', 'Sepsis',
#        'Malignant neoplasms', 'Diabetes', 'Obesity', 'Alzheimer disease',
#        'Vascular and unspecified dementia', 'Renal failure',
#        'Intentional and unintentional injury, poisoning, and other adverse events',
#        'All other conditions and causes (residual)', 'COVID-19'],
#       dtype=object)

# %%
#The number of condition groups
df['Condition_Group'].unique().size
# Out:
# 12

# %%
#Condition groups in a list
conditions = df['Condition_Group'].unique().tolist()
conditions
# Out:
# ['Respiratory diseases',
#  'Circulatory diseases',
#  'Sepsis',
#  'Malignant neoplasms',
#  'Diabetes',
#  'Obesity',
#  'Alzheimer disease',
#  'Vascular and unspecified dementia',
#  'Renal failure',
#  'Intentional and unintentional injury, poisoning, and other adverse events',
#  'All other conditions and causes (residual)',
#  'COVID-19']

# %%
#shorten names in condition group list for more compact labeling of visualizations

# %%
#Number of COVID-19 Deaths by Condition Group
df.groupby('Condition_Group')['COVID19_Deaths'].sum()
# Out:
# Condition_Group
# All other conditions and causes (residual)                                   2539428.0
# Alzheimer disease                                                             238424.0
# COVID-19                                                                     6666767.0
# Circulatory diseases                                                         4555687.0
# Diabetes                                                                     1059883.0
# Intentional and unintentional injury, poisoning, and other adverse events     124121.0
# Malignant neoplasms                                                           305611.0
# Obesity                                                                       252395.0
# Renal failure                                                                 654974.0
# Respiratory diseases                                                         7224449.0
# Sepsis                                                                        629049.0
# Vascular and unspecified dementia                                             653419.0
# Name: COVID19_Deaths, dtype: float64

# %% [markdown]
# # Percentage of COVID-19 Deaths by Condition Group - Bar Chart

# %%
#Table of Death per Age Groups
condition_deaths = df.groupby('Condition_Group')['COVID19_Deaths'].sum().reset_index()
condition_deaths
# Out:
#                                       Condition_Group  COVID19_Deaths
# 0          All other conditions and causes (residual)       2539428.0
# 1                                   Alzheimer disease        238424.0
# 2                                            COVID-19       6666767.0
# 3                                Circulatory diseases       4555687.0
# 4                                            Diabetes       1059883.0
# 5   Intentional and unintentional injury, poisonin...        124121.0
# 6                                 Malignant neoplasms        305611.0
# 7                                             Obesity        252395.0
# 8                                       Renal failure        654974.0
# 9                                Respiratory diseases       7224449.0
# 10                                             Sepsis        629049.0
# 11                  Vascular and unspecified dementia        653419.0

# %%
#Bar Chart of COVID-19 Deaths by Condition Group
condition_deaths.plot.bar(x = 'Condition_Group',y = 'COVID-19_Deaths')
plt.xlabel("Condition_Group")
plt.ylabel("Total COVID-19_Deaths")
plt.title('COVID-19 Deaths vs Condition_Group')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'COVID-19_Deaths'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-db59c6b246c0> in <module>
#       1 #Bar Chart of COVID-19 Deaths by Condition Group
# ----> 2 condition_deaths.plot.bar(x = 'Condition_Group',y = 'COVID-19_Deaths')
#       3 plt.xlabel("Condition_Group")
#       4 plt.ylabel("Total COVID-19_Deaths")
#       5 plt.title('COVID-19 Deaths vs Condition_Group')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     933
#     934                 # don't overwrite
# --> 935                 data = data[y].copy()
#     936
#     937                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'COVID-19_Deaths'

# %% [markdown]
# # Percentage of COVID-19 Deaths by Condition Group - Pie Chart

# %%
#Pie Chart showing percentage of COVID-19 Deaths by Age Group
condition_deaths.plot.pie(y = 'COVID-19_Deaths',labels = condition_deaths.Condition_Group, autopct="%1.2f%%" ,figsize=(10, 10))
plt.title("Respiratory diseases leading COVID-19 Deaths ")

# %% [markdown]
# # Removing COVID-19 as a condition of death to get a more accurate view of other factors contributing to deaths involving COVID-19

# %%
condition_deaths
# Out:
#                                       Condition_Group  COVID19_Deaths
# 0          All other conditions and causes (residual)       2539428.0
# 1                                   Alzheimer disease        238424.0
# 2                                            COVID-19       6666767.0
# 3                                Circulatory diseases       4555687.0
# 4                                            Diabetes       1059883.0
# 5   Intentional and unintentional injury, poisonin...        124121.0
# 6                                 Malignant neoplasms        305611.0
# 7                                             Obesity        252395.0
# 8                                       Renal failure        654974.0
# 9                                Respiratory diseases       7224449.0
# 10                                             Sepsis        629049.0
# 11                  Vascular and unspecified dementia        653419.0

# %%
#indexes with COVID-19 in the Condition_Group
covid = df[df['Condition_Group'] == 'COVID-19'].index
covid
# Out:
# Int64Index([   220,    221,    222,    223,    224,    225,    226,    227,
#                228,    229,
#             ...
#             235970, 235971, 235972, 235973, 235974, 235975, 235976, 235977,
#             235978, 235979],
#            dtype='int64', length=10260)

# %%
#drop the indexes with COVID-19 in the Condition_Group
df.drop(covid , inplace=True)

# %%
condition_deaths
# Out:
#                                       Condition_Group  COVID19_Deaths
# 0          All other conditions and causes (residual)       2539428.0
# 1                                   Alzheimer disease        238424.0
# 2                                            COVID-19       6666767.0
# 3                                Circulatory diseases       4555687.0
# 4                                            Diabetes       1059883.0
# 5   Intentional and unintentional injury, poisonin...        124121.0
# 6                                 Malignant neoplasms        305611.0
# 7                                             Obesity        252395.0
# 8                                       Renal failure        654974.0
# 9                                Respiratory diseases       7224449.0
# 10                                             Sepsis        629049.0
# 11                  Vascular and unspecified dementia        653419.0

# %%
#make sure the indexes are removed
df['Condition_Group'].unique().tolist()
# Out:
# ['Respiratory diseases',
#  'Circulatory diseases',
#  'Sepsis',
#  'Malignant neoplasms',
#  'Diabetes',
#  'Obesity',
#  'Alzheimer disease',
#  'Vascular and unspecified dementia',
#  'Renal failure',
#  'Intentional and unintentional injury, poisoning, and other adverse events',
#  'All other conditions and causes (residual)']

# %% [markdown]
# # Bar Chart

# %%
NoCOVIDcondition_deaths = df.groupby('Condition_Group')['COVID19_Deaths'].sum().reset_index()
NoCOVIDcondition_deaths
# Out:
#                                       Condition_Group  COVID19_Deaths
# 0          All other conditions and causes (residual)       2539428.0
# 1                                   Alzheimer disease        238424.0
# 2                                Circulatory diseases       4555687.0
# 3                                            Diabetes       1059883.0
# 4   Intentional and unintentional injury, poisonin...        124121.0
# 5                                 Malignant neoplasms        305611.0
# 6                                             Obesity        252395.0
# 7                                       Renal failure        654974.0
# 8                                Respiratory diseases       7224449.0
# 9                                              Sepsis        629049.0
# 10                  Vascular and unspecified dementia        653419.0

# %%
#Sort table by the number of covid deaths descending
NoCOVIDcondition_deaths.sort_values(['COVID19_Deaths'],ascending = False)
# Out:
#                                       Condition_Group  COVID19_Deaths
# 8                                Respiratory diseases       7224449.0
# 2                                Circulatory diseases       4555687.0
# 0          All other conditions and causes (residual)       2539428.0
# 3                                            Diabetes       1059883.0
# 7                                       Renal failure        654974.0
# 10                  Vascular and unspecified dementia        653419.0
# 9                                              Sepsis        629049.0
# 5                                 Malignant neoplasms        305611.0
# 6                                             Obesity        252395.0
# 1                                   Alzheimer disease        238424.0
# 4   Intentional and unintentional injury, poisonin...        124121.0

# %% [markdown]
# # Respiratory diseases contribute to most deaths involving COVID-19,followed by circulatory diseases.Intentional and unintentional injury, poisoning, and other adverse events contribute the least to deaths involving COVID-19

# %%
#Bar Chart of COVID-19 Deaths by Condition Group
NoCOVIDcondition_deaths.plot.bar(x = 'Condition_Group',y = 'COVID19_Deaths')
plt.xlabel("Condition_Group")
plt.ylabel("Total COVID19_Deaths")
plt.title('COVID-19 Deaths vs Condition_Group')
# Out:
# Text(0.5, 1.0, 'COVID-19 Deaths vs Condition_Group')

# %% [markdown]
# # Pie Chart

# %%
NoCOVIDcondition_deaths.plot.pie(y = 'COVID19_Deaths',labels = NoCOVIDcondition_deaths.Condition_Group, autopct="%1.2f%%" ,figsize=(10, 10))
plt.title("Respiratory diseases leading COVID-19 Deaths ")
# Out:
# Text(0.5, 1.0, 'Respiratory diseases leading COVID-19 Deaths ')

# %% [markdown]
# # Age groups

# %%
#all the age groups
df['Age_Group'].unique().tolist()#data[data['Value'] == True]
# Out:
# ['0-24',
#  '25-34',
#  '35-44',
#  '45-54',
#  '55-64',
#  '65-74',
#  '75-84',
#  '85+',
#  'Not stated',
#  'All Ages']

# %% [markdown]
# # I want to remove all rows with 'Not stated' and 'All Ages'in the Age Group column before visualizing the data

# %%
df[df['Age_Group'] == 'Not stated'].index
# Out:
# Int64Index([     8,     18,     28,     38,     48,     58,     68,     78,
#                 88,     98,
#             ...
#             235794, 235795, 235796, 235797, 235798, 235799, 235800, 235801,
#             235802, 235803],
#            dtype='int64', length=22572)

# %%
df[df['Age_Group'] == 'All Ages'].index
# Out:
# Int64Index([     9,     19,     29,     39,     49,     59,     69,     79,
#                 89,     99,
#             ...
#             235810, 235811, 235812, 235813, 235814, 235815, 235816, 235817,
#             235818, 235819],
#            dtype='int64', length=22572)

# %%
# Get indexes where Age Group column has value 'Not stated' or 'All Ages'
indexNames = df[(df['Age_Group'] == 'Not stated') | (df['Age_Group'] == 'All Ages')].index
print(indexNames)

# Delete these row indexes from dataFrame
df.drop(indexNames , inplace=True)
df.size
# Out:
# Int64Index([     8,      9,     18,     19,     28,     29,     38,     39,
#                 48,     49,
#             ...
#             235810, 235811, 235812, 235813, 235814, 235815, 235816, 235817,
#             235818, 235819],
#            dtype='int64', length=45144)
# 2528064

# %%
#make sure the indexes are removed
df['Age_Group'].unique().tolist()
# Out:
# ['0-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '85+']

# %%
#Death per Age Groups
age_group_deaths = df.groupby('Age_Group')['COVID19_Deaths'].sum().reset_index()
age_group_deaths
# Out:
#   Age_Group  COVID19_Deaths
# 0      0-24          9695.0
# 1     25-34         45281.0
# 2     35-44        133936.0
# 3     45-54        422475.0
# 4     55-64       1139929.0
# 5     65-74       2109344.0
# 6     75-84       2578187.0
# 7       85+       2602431.0

# %%
df['Age_Group'].unique().tolist()
# Out:
# ['0-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '85+']

# %%
age_group_deaths.plot.bar(x = 'Age_Group',y = 'COVID19_Deaths')
plt.xlabel("Age_Group")
plt.ylabel("Total COVID-19_Deaths")
plt.title('COVID-19 Deaths Increase With Increasing Age')
# Out:
# Text(0.5, 1.0, 'COVID-19 Deaths Increase With Increasing Age')

# %%
new = age_group_deaths.set_index('Age_Group')  #set index to the pieces going into the pie chart
new
# Out:
#            COVID19_Deaths
# Age_Group
# 0-24               9695.0
# 25-34             45281.0
# 35-44            133936.0
# 45-54            422475.0
# 55-64           1139929.0
# 65-74           2109344.0
# 75-84           2578187.0
# 85+             2602431.0

# %%
new = age_group_deaths.set_index('Age_Group')  #set index to the pieces going into the pie chart
new
new.plot.pie(y = 'COVID19_Deaths', figsize=(5, 5))
plt.title("COVID-19 Deaths Increase With Increasing Age")
# Out:
# Text(0.5, 1.0, 'COVID-19 Deaths Increase With Increasing Age')

# %%
#Pie Chart showing percentage of COVID-19 Deaths by Age Group
age_group_deaths.plot.pie(y = 'COVID19_Deaths',labels = age_group_deaths.Age_Group, autopct="%1.2f%%" ,figsize=(9, 9))
plt.title("COVID-19 Deaths Increase With Increasing Age") 

# ax = df_pie.plot.pie(y="Total Population", labels=df_pie.continent, autopct="%1.2f%%")
# # _ = ax.set_title("Asia is the most populous continent")
# plt.title("Asia is the most populous continent")
# Out:
# Text(0.5, 1.0, 'COVID-19 Deaths Increase With Increasing Age')

# %% [markdown]
# # SQL

# %%
# !pip install pandasql
#import pandasql as ps
from pandasql import sqldf

#lambda function that can make writing your queries easier
pysqldf = lambda q: sqldf(q, globals())

#output = sqldf("select * from df")
# Out:
# Requirement already satisfied: pandasql in c:\users\millie\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: sqlalchemy in c:\users\millie\anaconda3\lib\site-packages (from pandasql) (1.3.20)
# Requirement already satisfied: pandas in c:\users\millie\anaconda3\lib\site-packages (from pandasql) (1.1.3)
# Requirement already satisfied: numpy in c:\users\millie\anaconda3\lib\site-packages (from pandasql) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\millie\anaconda3\lib\site-packages (from pandas->pandasql) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\millie\anaconda3\lib\site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\millie\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %%
#select the whole dataframe 
q = """SELECT *
       FROM df 
       LIMIT 10;"""

sql_df = pysqldf(q)
sql_df
# Out:
#    Data_As_Of  Start_Date    End_Date     Group  Year Month          State  \
# 0  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 1  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 2  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 3  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 4  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 5  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 6  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 7  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 8  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 9  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
#
#         Condition_Group                           Condition ICD10_codes  \
# 0  Respiratory diseases             Influenza and pneumonia     J09-J18
# 1  Respiratory diseases             Influenza and pneumonia     J09-J18
# 2  Respiratory diseases             Influenza and pneumonia     J09-J18
# 3  Respiratory diseases             Influenza and pneumonia     J09-J18
# 4  Respiratory diseases             Influenza and pneumonia     J09-J18
# 5  Respiratory diseases             Influenza and pneumonia     J09-J18
# 6  Respiratory diseases             Influenza and pneumonia     J09-J18
# 7  Respiratory diseases             Influenza and pneumonia     J09-J18
# 8  Respiratory diseases  Chronic lower respiratory diseases     J40-J47
# 9  Respiratory diseases  Chronic lower respiratory diseases     J40-J47
#
#   Age_Group  COVID19_Deaths  Number_of_Mentions  Flag
# 0      0-24           370.0               384.0  None
# 1     25-34          1692.0              1731.0  None
# 2     35-44          4548.0              4664.0  None
# 3     45-54         13587.0             13964.0  None
# 4     55-64         34936.0             35852.0  None
# 5     65-74         61359.0             62804.0  None
# 6     75-84         71854.0             73129.0  None
# 7       85+         66033.0             66717.0  None
# 8      0-24            48.0                50.0  None
# 9     25-34           154.0               154.0  None

# %% [markdown]
# # Number of COVID19 Deaths by Age Group(Pandas then SQL)

# %%
#number of deaths by age-group
q = """SELECT Age_Group, SUM (COVID19_Deaths)
       FROM df
       GROUP BY Age_Group;"""

sql_df = pysqldf(q)
sql_df
# Out:
#   Age_Group  SUM (COVID19_Deaths)
# 0      0-24                9695.0
# 1     25-34               45281.0
# 2     35-44              133936.0
# 3     45-54              422475.0
# 4     55-64             1139929.0
# 5     65-74             2109344.0
# 6     75-84             2578187.0
# 7       85+             2602431.0

# %%
df.groupby('Age_Group')['COVID19_Deaths'].sum()
# Out:
# Age_Group
# 0-24        9695.0
# 25-34      45281.0
# 35-44     133936.0
# 45-54     422475.0
# 55-64    1139929.0
# 65-74    2109344.0
# 75-84    2578187.0
# 85+      2602431.0
# Name: COVID19_Deaths, dtype: float64

# %%
import sqlite3 as db
# Import df dataframe above to sqlite database
# Connect to a database (or create one if it doesn't exist)
conn = db.connect('data.db')
df.to_sql('df', conn, if_exists='replace', index=False)
pd.read_sql_query('SELECT * FROM df LIMIT 5', conn)
# Out:
#    Data_As_Of  Start_Date    End_Date     Group  Year Month          State  \
# 0  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 1  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 2  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 3  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 4  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
#
#         Condition_Group                Condition ICD10_codes Age_Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID19_Deaths  Number_of_Mentions  Flag
# 0           370.0               384.0  None
# 1          1692.0              1731.0  None
# 2          4548.0              4664.0  None
# 3         13587.0             13964.0  None
# 4         34936.0             35852.0  None

# %%
#Keep only relevant columns
query = '''SELECT Start_Date, End_Date,State, Condition_Group, Condition,Age_Group, COVID19_Deaths
            FROM df
          
'''

ans = pd.read_sql_query(query, conn)
ans
# Out:
#         Start_Date    End_Date          State  \
# 0       01/01/2020  04/24/2021  United States
# 1       01/01/2020  04/24/2021  United States
# 2       01/01/2020  04/24/2021  United States
# 3       01/01/2020  04/24/2021  United States
# 4       01/01/2020  04/24/2021  United States
# ...            ...         ...            ...
# 180571  12/01/2020  12/31/2020    Puerto Rico
# 180572  01/01/2021  01/31/2021    Puerto Rico
# 180573  02/01/2021  02/28/2021    Puerto Rico
# 180574  03/01/2021  03/31/2021    Puerto Rico
# 180575  04/01/2021  04/24/2021    Puerto Rico
#
#                                    Condition_Group  \
# 0                             Respiratory diseases
# 1                             Respiratory diseases
# 2                             Respiratory diseases
# 3                             Respiratory diseases
# 4                             Respiratory diseases
# ...                                            ...
# 180571  All other conditions and causes (residual)
# 180572  All other conditions and causes (residual)
# 180573  All other conditions and causes (residual)
# 180574  All other conditions and causes (residual)
# 180575  All other conditions and causes (residual)
#
#                                          Condition Age_Group  COVID19_Deaths
# 0                          Influenza and pneumonia      0-24           370.0
# 1                          Influenza and pneumonia     25-34          1692.0
# 2                          Influenza and pneumonia     35-44          4548.0
# 3                          Influenza and pneumonia     45-54         13587.0
# 4                          Influenza and pneumonia     55-64         34936.0
# ...                                            ...       ...             ...
# 180571  All other conditions and causes (residual)       85+            37.0
# 180572  All other conditions and causes (residual)       85+            22.0
# 180573  All other conditions and causes (residual)       85+             NaN
# 180574  All other conditions and causes (residual)       85+             NaN
# 180575  All other conditions and causes (residual)       85+             NaN
#
# [180576 rows x 7 columns]

# %% [markdown]
# # All rows in the dataframe with no null values in the COVID19_Deaths Column-Show only 5 rows

# %%
query = '''SELECT *
            FROM df
            WHERE COVID19_Deaths IS NOT NULL
            LIMIT 5'''
ans = pd.read_sql_query(query, conn)
ans
# Out:
#    Data_As_Of  Start_Date    End_Date     Group  Year Month          State  \
# 0  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 1  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 2  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 3  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
# 4  04/25/2021  01/01/2020  04/24/2021  By Total  None  None  United States
#
#         Condition_Group                Condition ICD10_codes Age_Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID19_Deaths  Number_of_Mentions  Flag
# 0           370.0               384.0  None
# 1          1692.0              1731.0  None
# 2          4548.0              4664.0  None
# 3         13587.0             13964.0  None
# 4         34936.0             35852.0  None

# %%
# 
# SELECT column_name(s)
# FROM table_name
# WHERE condition
# GROUP BY column_name(s)
# ORDER BY column_name(s);

# %% [markdown]
# # Total number of COVID19 Deaths in Each State as of 4/25/2021 in Descending Order

# %%
query = '''SELECT State, SUM(COVID19_Deaths)
            FROM df
            WHERE COVID19_Deaths IS NOT NULL AND State IS NOT 'United States'
            GROUP BY State
            ORDER BY SUM(COVID19_Deaths) DESC
            
'''

ans = pd.read_sql_query(query, conn)
ans
# Out:
#                    State  SUM(COVID19_Deaths)
# 0             California             594686.0
# 1                  Texas             449591.0
# 2                Florida             281475.0
# 3           Pennsylvania             204676.0
# 4             New Jersey             189619.0
# 5               New York             180697.0
# 6          New York City             172959.0
# 7               Illinois             165818.0
# 8                   Ohio             161560.0
# 9                Georgia             132533.0
# 10               Arizona             124298.0
# 11              Michigan             110278.0
# 12               Indiana             110172.0
# 13             Tennessee              96159.0
# 14         Massachusetts              94147.0
# 15              Maryland              79250.0
# 16        South Carolina              75171.0
# 17              Missouri              71424.0
# 18              Oklahoma              71026.0
# 19             Louisiana              70615.0
# 20               Alabama              69686.0
# 21             Wisconsin              66686.0
# 22             Minnesota              65833.0
# 23              Virginia              65096.0
# 24              Kentucky              64911.0
# 25           Mississippi              64365.0
# 26        North Carolina              63726.0
# 27              Colorado              57425.0
# 28           Connecticut              53302.0
# 29                Nevada              48694.0
# 30            Washington              45238.0
# 31                  Iowa              43651.0
# 32              Arkansas              43521.0
# 33                Kansas              34788.0
# 34            New Mexico              24150.0
# 35              Nebraska              22608.0
# 36          Rhode Island              17980.0
# 37         West Virginia              17611.0
# 38                  Utah              17026.0
# 39                Oregon              16609.0
# 40          South Dakota              15902.0
# 41                 Idaho              14991.0
# 42           Puerto Rico              14587.0
# 43  District of Columbia              12625.0
# 44               Montana              12334.0
# 45          North Dakota              11533.0
# 46         New Hampshire               6867.0
# 47              Delaware               4836.0
# 48               Wyoming               3686.0
# 49                 Maine               3018.0
# 50                Hawaii               1797.0
# 51                Alaska                954.0
# 52               Vermont                817.0

# %% [markdown]
# # Total number of COVID19 Deaths in Each State as of 4/25/2021 By Condition_Group

# %%
query = '''SELECT State, Condition_Group, SUM(COVID19_Deaths) as Deaths
            FROM df
            WHERE COVID19_Deaths IS NOT NULL AND State IS NOT 'United States'
            GROUP BY State, Condition_Group
            ORDER BY Deaths DESC
            
'''

ans = pd.read_sql_query(query, conn)
ans
# Out:
#           State       Condition_Group    Deaths
# 0    California  Respiratory diseases  240679.0
# 1         Texas  Respiratory diseases  174865.0
# 2    California  Circulatory diseases  158811.0
# 3       Florida  Respiratory diseases  106235.0
# 4         Texas  Circulatory diseases  102844.0
# ..          ...                   ...       ...
# 578     Vermont   Malignant neoplasms       0.0
# 579     Vermont               Obesity       0.0
# 580     Vermont         Renal failure       0.0
# 581     Vermont                Sepsis       0.0
# 582     Wyoming               Obesity       0.0
#
# [583 rows x 3 columns]

# %% [markdown]
# # Find unique values for the end date

# %%
query = '''SELECT DISTINCT End_Date
            FROM df
            
          
'''

ans = pd.read_sql_query(query, conn)
ans
# Out:
#       End_Date
# 0   04/24/2021
# 1   12/31/2020
# 2   01/31/2020
# 3   02/29/2020
# 4   03/31/2020
# 5   04/30/2020
# 6   05/31/2020
# 7   06/30/2020
# 8   07/31/2020
# 9   08/28/2020
# 10  09/30/2020
# 11  10/31/2020
# 12  11/30/2020
# 13  01/31/2021
# 14  02/28/2021
# 15  03/31/2021

# %% [markdown]
# # Total number of COVID19 Deaths in Each State in 2020 and in Descending Order¶

# %%
query = '''SELECT State, SUM(COVID19_Deaths) as Deaths
            FROM df
            WHERE COVID19_Deaths IS NOT NULL AND State IS NOT 'United States' AND End_Date BETWEEN '01/01/2020' and '12/31/2020'

            GROUP BY State
            ORDER BY Deaths DESC
         
'''

ans = pd.read_sql_query(query, conn)
ans
# Out:
#                    State    Deaths
# 0             California  594686.0
# 1                  Texas  449591.0
# 2                Florida  281475.0
# 3           Pennsylvania  204676.0
# 4             New Jersey  189619.0
# 5               New York  180697.0
# 6          New York City  172959.0
# 7               Illinois  165818.0
# 8                   Ohio  161560.0
# 9                Georgia  132533.0
# 10               Arizona  124298.0
# 11              Michigan  110278.0
# 12               Indiana  110172.0
# 13             Tennessee   96159.0
# 14         Massachusetts   94147.0
# 15              Maryland   79250.0
# 16        South Carolina   75171.0
# 17              Missouri   71424.0
# 18              Oklahoma   71026.0
# 19             Louisiana   70615.0
# 20               Alabama   69686.0
# 21             Wisconsin   66686.0
# 22             Minnesota   65833.0
# 23              Virginia   65096.0
# 24              Kentucky   64911.0
# 25           Mississippi   64365.0
# 26        North Carolina   63726.0
# 27              Colorado   57425.0
# 28           Connecticut   53302.0
# 29                Nevada   48694.0
# 30            Washington   45238.0
# 31                  Iowa   43651.0
# 32              Arkansas   43521.0
# 33                Kansas   34788.0
# 34            New Mexico   24150.0
# 35              Nebraska   22608.0
# 36          Rhode Island   17980.0
# 37         West Virginia   17611.0
# 38                  Utah   17026.0
# 39                Oregon   16609.0
# 40          South Dakota   15902.0
# 41                 Idaho   14991.0
# 42           Puerto Rico   14587.0
# 43  District of Columbia   12625.0
# 44               Montana   12334.0
# 45          North Dakota   11533.0
# 46         New Hampshire    6867.0
# 47              Delaware    4836.0
# 48               Wyoming    3686.0
# 49                 Maine    3018.0
# 50                Hawaii    1797.0
# 51                Alaska     954.0
# 52               Vermont     817.0
